# %%
# %store -r fff # 训练集
# %store -r ttt # 测试集
# Out:
# no stored variable # 训练集
# no stored variable # 测试集

# %%
import pandas as pd
from pandas import DataFrame,Series
from numpy import *

# %%
from hmmlearn import hmm
model = hmm.GaussianHMM(n_components=8,n_iter=50)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.externals import joblib

# %%
model.monitor_
# Out:
# ConvergenceMonitor(history=[178233.96423209124, 178239.20541037747], iter=50,
#           n_iter=50, tol=0.01, verbose=False)

# %%
traincol=fff[['v','u']]

# %%
array(traincol)
# Out:
# array([[  0.        ,   0.        ],
#        [  0.        ,   0.        ],
#        [ 45.2577176 ,  45.2577176 ],
#        ...,
#        [ 34.09614324,  34.09614324],
#        [  8.27      ,  36.9827755 ],
#        [  0.        ,   8.27      ]])

# %%
# %%time
model.fit(traincol,lengths=[1600]*(len(traincol)/1600))
# Out:
# /home/liheyuan/ENV/local/lib/python2.7/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function distribute_covar_matrix_to_match_covariance_type is deprecated; The function distribute_covar_matrix_to_match_covariance_typeis deprecated in 0.18 and will be removed in 0.20.
#   warnings.warn(msg, category=DeprecationWarning)
# /home/liheyuan/ENV/local/lib/python2.7/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function log_multivariate_normal_density is deprecated; The function log_multivariate_normal_density is deprecated in 0.18 and will be removed in 0.20.
#   warnings.warn(msg, category=DeprecationWarning)
# /home/liheyuan/ENV/local/lib/python2.7/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function log_multivariate_normal_density is deprecated; The function log_multivariate_normal_density is deprecated in 0.18 and will be removed in 0.20.
#   warnings.warn(msg, category=DeprecationWarning)
# ...

# %%
from funcs import next_v_to_predict_next_position,vec_distance
#以下可以考虑拉出来当做函数，反正基本上已经封装完了

# 传入由于测试的数据
test_df = fff
# 传入用于训练的数据(这里并没有训练，只是找出state对应的特征值)
train_df = fff
# 传入观测点(基准点)
base_point = 1000
# 传入答案点
anwser_point = 1001

# 指定用于训练和预测的列
traincol =  array(test_df[['v','u']])

Z = model.decode(traincol)
test_df['label'] = DataFrame(Z[1])

state_num = len(model.startprob_)

print '---------*观察报告*---------'
print '每种状态对应的轨迹数'
for i in range(state_num):
    tmp = test_df[test_df['label']==i]
    print '状态',i,'有',len(tmp),'条轨迹'

# 从均值的角度观察一下数据，发现确实是有效果的，并将状态对应的v储存
tmp = 0
state_v=[]
print '每种状态对应的速度和加速度'
for tmp in range(state_num):
    print mean(train_df[train_df['label']==tmp].v)
    print mean(train_df[train_df['label']==tmp].u)
    state_v.append(mean(train_df[train_df['label']==tmp].v)+mean(train_df[train_df['label']==tmp].u))
#     print(mean(test_df[test_df['label']==tmp].v)+mean(test_df[test_df['label']==tmp].u))
print state_v

# 每条轨迹长度
length = len(test_df[test_df['id']==0])
# 轨迹数
car_num = int(max(array([test_df['id']]).flatten())-min(array([test_df['id']]).flatten())+1)
print '每条轨迹长度:',length
print '轨迹数:',car_num

# 设置基准点和答案点
base_points = test_df.iloc[[i*length+base_point for i in range(car_num)]]                     #
anwser_points = test_df.iloc[[i*length+anwser_point for i in range(car_num)]]

base_points_v = array(base_points[['v','u']])

state_v_col_vec = array(state_v).reshape(-1,1)

# 上一点状态的概率矩阵
last_states_proba = model.predict_proba(base_points_v) #这里没有设置length，但是有可能需要，否则有可能被当做是同一个序列
# 下一点状态的概率矩阵
predict_proba_next_points = dot(last_states_proba,model.transmat_)
# 通过下一点状态的概率矩阵进行对应速度均值，得出的预测速度
predict_next_points_v = dot(predict_proba_next_points,state_v_col_vec)

predict_next_position = []
tmp=0
predict_next_points_v = predict_next_points_v.flatten()
for base_point in base_points.itertuples():
    predict_next_position.append(next_v_to_predict_next_position(predict_next_points_v[tmp],base_point))
    tmp+=1
    
predict_next_position = array(predict_next_position)
print '取前5个预测点观察'
print predict_next_position[:5]
# Out:
# ---------*观察报告*---------
# 每种状态对应的轨迹数
# 状态 0 有 21519 条轨迹
# 状态 1 有 692 条轨迹
# 状态 2 有 1848 条轨迹
# 状态 3 有 1 条轨迹
# 状态 4 有 3749 条轨迹
# 状态 5 有 1 条轨迹
# 状态 6 有 1658 条轨迹
# 状态 7 有 2532 条轨迹
# 每种状态对应的速度和加速度
# 0.0
# 0.0
# 367.633470528
# 326.873056731
# 119.41620698
# 73.6993347146
# 7105.22511049
# 7105.22511049
# 28.6462043904
# 21.2293872193
# 641.233277855
# 7676.93628693
# 0.0
# 35.74149053
# 68.8630439667
# 27.4325398219
# [0.0, 694.50652725933344, 193.11554169422331, 14210.450220979999, 49.875591609775654, 8318.1695647850011, 35.741490529972317, 96.295583788585574]
# 每条轨迹长度: 1600
# 轨迹数: 20
# 取前5个预测点观察
# [[  39835.96164253   96112.0075554 ]
#  [  32011.16051796   97902.87150669]
#  [  40126.62396141  101159.38799589]
#  [  34581.0431799   110025.14549608]
#  [  28527.74739842   97841.38134995]]
# ...

# %%
errs = vec_distance(array(anwser_points.x),array(anwser_points.y),predict_next_position[:,0],predict_next_position[:,1])
print mean(errs)
# Out:
# 69.139912766

# %%
errs = vec_distance(array(anwser_points.x),array(anwser_points.y),predict_next_position[:,0],predict_next_position[:,1])
print mean(errs)
# Out:
# 52.9096970365

# %%
reload(funcs)
# Out:
# <module 'funcs' from 'funcs.py'>

# %%
funcs.prediction(model,fff,ttt,traincol_name=['v','u'])
# Out:
# [[   0.            0.        ]
#  [   0.            0.        ]
#  [   0.            0.        ]
#  ...,
#  [ 129.07179165   39.8119505 ]
#  [ 122.65182661   11.62884597]
#  [ 138.33170396   17.02417556]]
# ---------*观察报告*---------
# 每种状态对应的轨迹数
# 状态 0 有 30083 条轨迹
# 状态 1 有 764 条轨迹
# 状态 2 有 1998 条轨迹
# 状态 3 有 0 条轨迹
# 状态 4 有 3822 条轨迹
# 状态 5 有 0 条轨迹
# 状态 6 有 1762 条轨迹
# 状态 7 有 3571 条轨迹
# 每种状态对应的速度
# [[0.0, 0.0, 0.0, 43.136112272875131], [367.63347052789607, 326.87305673143737, 0.02910254269895219, 0.066473988439306353], [119.41620697962549, 73.699334714597825, -3.9643196162317329, 0.0], [7105.2251104899997, 7105.2251104899997, 2.0251201678999999, 0.0], [28.646204390425673, 21.229387219349977, -5.5731189406749291, 0.0], [641.23327785499998, 7676.9362869300003, 179.77218017499999, 0.0], [0.0, 35.741490529972317, -16.563862970914446, 0.99939686369119418], [68.863043966676926, 27.432539821908648, -0.27063403502783928, 0.0]]
# 每条轨迹长度: 2100
# 轨迹数: 20
# ...

# %%
model_test_v_u_diata_stops_12m2d19h48min = hmm.GaussianHMM(n_components=12,n_iter=50)

# %%
cdf = pd.read_csv('../middata/cdf1.csv',index_col=0)

# %%
# traincol = cdf[:100*1600]
traincol = cdf

# %%
# testcol = cdf[100*1600:200*1600]
ctdf = pd.read_csv('../middata/ctdf1.csv',index_col=0)
testcol = ctdf
# Out:
# /home/liheyuan/ENV/local/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
model_test_v_u_diata_stops_12m2d19h48min.fit(traincol,lengths=[1600]*(len(traincol)/1600))
# Out:
# /home/liheyuan/ENV/local/lib/python2.7/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function distribute_covar_matrix_to_match_covariance_type is deprecated; The function distribute_covar_matrix_to_match_covariance_typeis deprecated in 0.18 and will be removed in 0.20.
#   warnings.warn(msg, category=DeprecationWarning)
# /home/liheyuan/ENV/local/lib/python2.7/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function log_multivariate_normal_density is deprecated; The function log_multivariate_normal_density is deprecated in 0.18 and will be removed in 0.20.
#   warnings.warn(msg, category=DeprecationWarning)
# /home/liheyuan/ENV/local/lib/python2.7/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function log_multivariate_normal_density is deprecated; The function log_multivariate_normal_density is deprecated in 0.18 and will be removed in 0.20.
#   warnings.warn(msg, category=DeprecationWarning)
# ...

# %%
joblib.dump(model_test_v_u_diata_stops_12m2d19h48min,'../models/model_test_v_u_diata_stops_12m2d19h48min')
# Out:
# ['../models/model_test_v_u_diata_stops_12m2d19h48min']

# %%
model_test_v_u_diata_stops_12m2d19h48min.monitor_
# Out:
# ConvergenceMonitor(history=[1498013.9327357248, 1498013.9410016187], iter=48,
#           n_iter=50, tol=0.01, verbose=False)

# %%
reload(funcs)
funcs.prediction(model_check,traincol,testcol,traincol_name=['v','u','diata'])
# Out:
# /home/liheyuan/ENV/local/lib/python2.7/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function log_multivariate_normal_density is deprecated; The function log_multivariate_normal_density is deprecated in 0.18 and will be removed in 0.20.
#   warnings.warn(msg, category=DeprecationWarning)
# /home/liheyuan/ENV/local/lib/python2.7/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function log_multivariate_normal_density is deprecated; The function log_multivariate_normal_density is deprecated in 0.18 and will be removed in 0.20.
#   warnings.warn(msg, category=DeprecationWarning)
# ---------*观察报告*---------
# 每种状态对应的轨迹数
# 状态 0 有 16330976 条轨迹
# 状态 1 有 282182 条轨迹
# 状态 2 有 374622 条轨迹
# 状态 3 有 116640 条轨迹
# 状态 4 有 156146 条轨迹
# 状态 5 有 255201 条轨迹
# 状态 6 有 61931 条轨迹
# 状态 7 有 547442 条轨迹
# 状态 8 有 782109 条轨迹
# 状态 9 有 255575 条轨迹
# 状态 10 有 361671 条轨迹
# 状态 11 有 533905 条轨迹
# 状态 12 有 169823 条轨迹
# 状态 13 有 237084 条轨迹
# 状态 14 有 387274 条轨迹
# 状态 15 有 147419 条轨迹
# ...

# %%
model_check = joblib.load('../models/model_2000_car_300_iter_v_u_diata_12m2d21h31min.pkl')

# %%
model_2000_car_200_iter_12m1d7h47min = joblib.load('../models/model_2000_car_200_iter_12m1d7h47min.pkl')

# %%
funcs.prediction(model_2000_car_200_iter_12m1d7h47min,traincol,testcol,traincol_name=['v'])
# Out:
# /home/liheyuan/ENV/local/lib/python2.7/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function log_multivariate_normal_density is deprecated; The function log_multivariate_normal_density is deprecated in 0.18 and will be removed in 0.20.
#   warnings.warn(msg, category=DeprecationWarning)
# /home/liheyuan/ENV/local/lib/python2.7/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function log_multivariate_normal_density is deprecated; The function log_multivariate_normal_density is deprecated in 0.18 and will be removed in 0.20.
#   warnings.warn(msg, category=DeprecationWarning)
# ---------*观察报告*---------
# 每种状态对应的轨迹数
# 状态 0 有 17140354 条轨迹
# 状态 1 有 480730 条轨迹
# 状态 2 有 266469 条轨迹
# 状态 3 有 617067 条轨迹
# 状态 4 有 2208 条轨迹
# 状态 5 有 246903 条轨迹
# 状态 6 有 19892 条轨迹
# 状态 7 有 0 条轨迹
# 状态 8 有 222270 条轨迹
# 状态 9 有 571022 条轨迹
# 状态 10 有 103542 条轨迹
# 状态 11 有 99308 条轨迹
# 状态 12 有 211646 条轨迹
# 状态 13 有 264379 条轨迹
# 状态 14 有 749180 条轨迹
# 状态 15 有 5030 条轨迹
# 每种状态对应的观测
# ...

# %%
model1 = joblib.load('../models/model1.pkl')

# %%
funcs.prediction(model1,traincol,testcol,traincol_name=['v'])
# Out:
# /home/liheyuan/ENV/local/lib/python2.7/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function log_multivariate_normal_density is deprecated; The function log_multivariate_normal_density is deprecated in 0.18 and will be removed in 0.20.
#   warnings.warn(msg, category=DeprecationWarning)
# /home/liheyuan/ENV/local/lib/python2.7/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function log_multivariate_normal_density is deprecated; The function log_multivariate_normal_density is deprecated in 0.18 and will be removed in 0.20.
#   warnings.warn(msg, category=DeprecationWarning)
# ---------*观察报告*---------
# 每种状态对应的轨迹数
# 状态 0 有 17149700 条轨迹
# 状态 1 有 457652 条轨迹
# 状态 2 有 832210 条轨迹
# 状态 3 有 489572 条轨迹
# 状态 4 有 11923 条轨迹
# 状态 5 有 116474 条轨迹
# 状态 6 有 303555 条轨迹
# 状态 7 有 1638914 条轨迹
# 每种状态对应的观测
# 每条轨迹长度: 2100
# 轨迹数: 10000
# 观测状态矩阵
# [[  0.00000000e+00   2.87527523e+00  -5.94848698e-01   8.04037884e+01]
# ...

# %%
new_traincol = cdf[:1600]

# %%
funcs.prediction(model_2000_car_200_iter_12m1d7h47min,new_traincol,new_traincol,traincol_name=['v'])
# Out:
# /home/liheyuan/ENV/local/lib/python2.7/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function log_multivariate_normal_density is deprecated; The function log_multivariate_normal_density is deprecated in 0.18 and will be removed in 0.20.
#   warnings.warn(msg, category=DeprecationWarning)
# ---------*观察报告*---------
# 每种状态对应的轨迹数
# 状态 0 有 1120 条轨迹
# 状态 1 有 80 条轨迹
# 状态 2 有 27 条轨迹
# 状态 3 有 63 条轨迹
# 状态 4 有 0 条轨迹
# 状态 5 有 38 条轨迹
# 状态 6 有 10 条轨迹
# 状态 7 有 0 条轨迹
# 状态 8 有 22 条轨迹
# 状态 9 有 30 条轨迹
# 状态 10 有 20 条轨迹
# 状态 11 有 6 条轨迹
# 状态 12 有 47 条轨迹
# 状态 13 有 49 条轨迹
# 状态 14 有 87 条轨迹
# 状态 15 有 1 条轨迹
# 每种状态对应的观测
# 每条轨迹长度: 1600
# 轨迹数: 1
# 观测状态矩阵
# [[  0.00000000e+00   5.68904621e+00   1.38610356e+00   1.27187500e+01]
#  [  5.82876750e+01   6.02835333e+01  -7.76654885e+00   0.00000000e+00]
#  [  3.20363524e+02   2.12863554e+02  -9.04642991e+00   0.00000000e+00]
#  [  4.52449533e+01   3.00337327e+01   3.30243750e+00   0.00000000e+00]
# ...

# %%
model_tmp = hmm.GaussianHMM(n_components=8,n_iter=50)
model_tmp.fit(new_traincol['v'].reshape(-1,1))
# Out:
# /home/liheyuan/ENV/lib/python2.7/site-packages/ipykernel_launcher.py:2: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#
# /home/liheyuan/ENV/local/lib/python2.7/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function distribute_covar_matrix_to_match_covariance_type is deprecated; The function distribute_covar_matrix_to_match_covariance_typeis deprecated in 0.18 and will be removed in 0.20.
#   warnings.warn(msg, category=DeprecationWarning)
# /home/liheyuan/ENV/local/lib/python2.7/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function log_multivariate_normal_density is deprecated; The function log_multivariate_normal_density is deprecated in 0.18 and will be removed in 0.20.
#   warnings.warn(msg, category=DeprecationWarning)
# ...

# %%
funcs.prediction(model_tmp,new_traincol,new_traincol,traincol_name=['v'])
# Out:
# /home/liheyuan/ENV/local/lib/python2.7/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function log_multivariate_normal_density is deprecated; The function log_multivariate_normal_density is deprecated in 0.18 and will be removed in 0.20.
#   warnings.warn(msg, category=DeprecationWarning)
# ---------*观察报告*---------
# 每种状态对应的轨迹数
# 状态 0 有 1121 条轨迹
# 状态 1 有 1 条轨迹
# 状态 2 有 80 条轨迹
# 状态 3 有 155 条轨迹
# 状态 4 有 13 条轨迹
# 状态 5 有 53 条轨迹
# 状态 6 有 48 条轨迹
# 状态 7 有 129 条轨迹
# 每种状态对应的观测
# 每条轨迹长度: 1600
# 轨迹数: 1
# 观测状态矩阵
# [[    0.             0.             0.             0.        ]
#  [ 7105.22511049     0.             0.             0.        ]
#  [  226.97472483     0.             0.             0.        ]
#  [   35.82390686     0.             0.             0.        ]
#  [  855.6082248      0.             0.             0.        ]
#  [   67.75226375     0.             0.             0.        ]
#  [   12.80187654     0.             0.             0.        ]
# ...

# %%
# 单个模型
model_tmp = hmm.GaussianHMM(n_components=8,n_iter=50)
model_tmp.fit(new_traincol['v'].reshape(-1,1))

# %%
funcs.prediction(model_2000_car_200_iter_12m1d7h47min,cdf,ctdf,traincol_name=['v'])
# Out:
# /home/liheyuan/ENV/local/lib/python2.7/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function log_multivariate_normal_density is deprecated; The function log_multivariate_normal_density is deprecated in 0.18 and will be removed in 0.20.
#   warnings.warn(msg, category=DeprecationWarning)
# /home/liheyuan/ENV/local/lib/python2.7/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function log_multivariate_normal_density is deprecated; The function log_multivariate_normal_density is deprecated in 0.18 and will be removed in 0.20.
#   warnings.warn(msg, category=DeprecationWarning)
# ---------*观察报告*---------
# 每种状态对应的轨迹数
# 状态 0 有 17140354 条轨迹
# 状态 1 有 480730 条轨迹
# 状态 2 有 266469 条轨迹
# 状态 3 有 617067 条轨迹
# 状态 4 有 2208 条轨迹
# 状态 5 有 246903 条轨迹
# 状态 6 有 19892 条轨迹
# 状态 7 有 0 条轨迹
# 状态 8 有 222270 条轨迹
# 状态 9 有 571022 条轨迹
# 状态 10 有 103542 条轨迹
# 状态 11 有 99308 条轨迹
# 状态 12 有 211646 条轨迹
# 状态 13 有 264379 条轨迹
# 状态 14 有 749180 条轨迹
# 状态 15 有 5030 条轨迹
# 每种状态对应的观测
# ...

# %%
reload(funcs)
funcs.prediction(model_2000_car_200_iter_12m1d7h47min,cdf,ctdf,traincol_name=['v'])
# Out:
# /home/liheyuan/ENV/local/lib/python2.7/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function log_multivariate_normal_density is deprecated; The function log_multivariate_normal_density is deprecated in 0.18 and will be removed in 0.20.
#   warnings.warn(msg, category=DeprecationWarning)
# /home/liheyuan/ENV/local/lib/python2.7/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function log_multivariate_normal_density is deprecated; The function log_multivariate_normal_density is deprecated in 0.18 and will be removed in 0.20.
#   warnings.warn(msg, category=DeprecationWarning)
# ---------*观察报告*---------
# 每种状态对应的轨迹数
# 状态 0 有 17140354 条轨迹
# 状态 1 有 480730 条轨迹
# 状态 2 有 266469 条轨迹
# 状态 3 有 617067 条轨迹
# 状态 4 有 2208 条轨迹
# 状态 5 有 246903 条轨迹
# 状态 6 有 19892 条轨迹
# 状态 7 有 0 条轨迹
# 状态 8 有 222270 条轨迹
# 状态 9 有 571022 条轨迹
# 状态 10 有 103542 条轨迹
# 状态 11 有 99308 条轨迹
# 状态 12 有 211646 条轨迹
# 状态 13 有 264379 条轨迹
# 状态 14 有 749180 条轨迹
# 状态 15 有 5030 条轨迹
# 每种状态对应的观测
# ...

# %%
model_tmp = hmm.GaussianHMM(n_components=8,n_iter=50)
model_tmp.fit(new_traincol[['v']])
funcs.prediction(model_tmp,new_traincol,new_traincol,traincol_name=['v'])
# Out:
# /home/liheyuan/ENV/local/lib/python2.7/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function distribute_covar_matrix_to_match_covariance_type is deprecated; The function distribute_covar_matrix_to_match_covariance_typeis deprecated in 0.18 and will be removed in 0.20.
#   warnings.warn(msg, category=DeprecationWarning)
# /home/liheyuan/ENV/local/lib/python2.7/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function log_multivariate_normal_density is deprecated; The function log_multivariate_normal_density is deprecated in 0.18 and will be removed in 0.20.
#   warnings.warn(msg, category=DeprecationWarning)
# /home/liheyuan/ENV/local/lib/python2.7/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function log_multivariate_normal_density is deprecated; The function log_multivariate_normal_density is deprecated in 0.18 and will be removed in 0.20.
#   warnings.warn(msg, category=DeprecationWarning)
# ...

# %%
model_tmp.monitor_
# Out:
# ConvergenceMonitor(history=[2433.0845503439314, 2433.0942600304679], iter=81,
#           n_iter=100, tol=0.01, verbose=False)

# %%
(39850.1448953+39848.24329176)/2,(96116.52198752+96108.94862623)/2
# Out:
# (39849.19409353, 96112.735306875)

# %%
sqrt((cdf.iloc[1001].x-(39850.1448953+39848.24329176)/2)**2+(cdf.iloc[1001].y-(96116.52198752+96108.94862623)/2)**2)
# Out:
# 9.9594187089334341

# %%
ptmp1
# Out:
# array([[ 39839.12619191,  96108.7790564 ]])

# %%
atmp1
# Out:
#        id           x          y    v      theta    u  diata  stops_time  \
# 1001  0.0  39842.0482  96105.798  0.0  134.42689  0.0    0.0         4.0
#
#       label
# 1001      0

# %%
reload(funcs)
funcs.self_prediction(model_2000_car_200_iter_12m1d7h47min,cdf,cdf[cdf['id']<50],traincol_name=['v'],weight_predict_base_all=0.85)
# Out:
# ---------*观察报告*---------
# 每种状态对应的轨迹数
# 状态 0 有 60184 条轨迹
# 状态 1 有 2374 条轨迹
# 状态 2 有 1126 条轨迹
# 状态 3 有 3457 条轨迹
# 状态 4 有 0 条轨迹
# 状态 5 有 1179 条轨迹
# 状态 6 有 59 条轨迹
# 状态 7 有 0 条轨迹
# 状态 8 有 1059 条轨迹
# 状态 9 有 3000 条轨迹
# 状态 10 有 480 条轨迹
# 状态 11 有 389 条轨迹
# 状态 12 有 1308 条轨迹
# 状态 13 有 1282 条轨迹
# 状态 14 有 4102 条轨迹
# 状态 15 有 1 条轨迹
# 每种状态对应的观测
# 每条轨迹长度: 1600
# 轨迹数: 50
# 观测状态矩阵
# [[  0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00]
#  [  6.10505636e+01   0.00000000e+00   0.00000000e+00   0.00000000e+00]
#  [  3.09428371e+02   0.00000000e+00   0.00000000e+00   0.00000000e+00]
#  [  4.38698485e+01   0.00000000e+00   0.00000000e+00   0.00000000e+00]
#  [  9.17854605e+03   0.00000000e+00   0.00000000e+00   0.00000000e+00]
#  [  1.56911230e+02   0.00000000e+00   0.00000000e+00   0.00000000e+00]
#  [  1.19635438e+03   0.00000000e+00   0.00000000e+00   0.00000000e+00]
#  [  3.00105223e+04   0.00000000e+00   0.00000000e+00   0.00000000e+00]
# ...

# %%
tmp = funcs.prediction(model_2000_car_200_iter_12m1d7h47min,fff,ttt,traincol_name=['v'])
# Out:
# /home/liheyuan/ENV/local/lib/python2.7/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function log_multivariate_normal_density is deprecated; The function log_multivariate_normal_density is deprecated in 0.18 and will be removed in 0.20.
#   warnings.warn(msg, category=DeprecationWarning)
# /home/liheyuan/ENV/local/lib/python2.7/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function log_multivariate_normal_density is deprecated; The function log_multivariate_normal_density is deprecated in 0.18 and will be removed in 0.20.
#   warnings.warn(msg, category=DeprecationWarning)
# ---------*观察报告*---------
# 每种状态对应的轨迹数
# 状态 0 有 31896 条轨迹
# 状态 1 有 1134 条轨迹
# 状态 2 有 506 条轨迹
# 状态 3 有 1853 条轨迹
# 状态 4 有 0 条轨迹
# 状态 5 有 506 条轨迹
# 状态 6 有 11 条轨迹
# 状态 7 有 0 条轨迹
# 状态 8 有 499 条轨迹
# 状态 9 有 1707 条轨迹
# 状态 10 有 195 条轨迹
# 状态 11 有 141 条轨迹
# 状态 12 有 538 条轨迹
# 状态 13 有 905 条轨迹
# 状态 14 有 2109 条轨迹
# 状态 15 有 0 条轨迹
# 每种状态对应的观测
# 每条轨迹长度: 2100
# 轨迹数: 20
# 观测状态矩阵
# ...

# %%
tmp[0]
# Out:
# array([ 4.39082688,  0.        ,  0.        ,  0.        ])

# %%
tmp = [1,2]

# %%
tmp.append(3)
